# %%
from google.colab import ai
response = ai.generate_text("What is the capital of France?")
# Out:
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# /tmp/ipython-input-952515708.py in <cell line: 0>()
#       1 from google.colab import ai
# ----> 2 response = ai.generate_text("What is the capital of France?")
#
# /usr/local/lib/python3.12/dist-packages/google/colab/ai.py in generate_text(prompt, model_name, stream)
#      76     )
#      77
# ---> 78   model_proxy_token = _get_model_proxy_token()
#      79
#      80   client = _OpenAI(
#
# /usr/local/lib/python3.12/dist-packages/google/colab/ai.py in _get_model_proxy_token()
#     109     return _os.environ['MODEL_PROXY_API_KEY']
#     110
# --> 111   model_proxy_token = _userdata.get('MODEL_PROXY_API_KEY')
#     112   _os.environ['MODEL_PROXY_API_KEY'] = model_proxy_token
#     113   return model_proxy_token
#
# /usr/local/lib/python3.12/dist-packages/google/colab/userdata.py in get(key)
#      64     )
#      65   if not resp:
# ---> 66     raise TimeoutException(key)
#      67   if not resp.get('exists', False):
#      68     raise SecretNotFoundError(key)
#
# TimeoutException: Requesting secret MODEL_PROXY_API_KEY timed out. Secrets can only be fetched when running from the Colab UI.

# %%
from google.colab import userdata
userdata.get('secretName')
# Out:
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# /tmp/ipython-input-3196339759.py in <cell line: 0>()
#       1 from google.colab import userdata
# ----> 2 userdata.get('secretName')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/userdata.py in get(key)
#      64     )
#      65   if not resp:
# ---> 66     raise TimeoutException(key)
#      67   if not resp.get('exists', False):
#      68     raise SecretNotFoundError(key)
#
# TimeoutException: Requesting secret secretName timed out. Secrets can only be fetched when running from the Colab UI.

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %%
from transformers import pipeline
generator = pipeline('text-generation', model='gpt2')
print(generator("Hello, world!"))
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "Hello, world! I've been dreaming about this whole game ever since I was a kid! What an amazing feeling to be surrounded by so many beautiful, wonderful people, and to have the opportunity to have the opportunity to play with so many different people!\n\nI'm so excited to be playing with some amazing people!\n\nAnd I'm so proud of the fact that I can finally be a part of the team that brings you the greatest stuff.\n\nSo, if you're a beginner, how would you describe yourself in these interviews?\n\nI would say that I'm a fairly normal kid who has been raised in a family of gamers for awhile. I've never been interested in games before, but I started playing them at age 9 at a very young age. I still love them, but I'm not really into all the genres. I played a lot of video games, but I was always a beginner about it. But I got my MFA in video game design from the same school as me. And I'm very proud of it.\n\nI've been doing this for so long, it's so exciting to start something new. I love the game of video games!\n\nDo you have any favorite games of all time?\n\nI love Mario"}]
